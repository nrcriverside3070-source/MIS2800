# %% [markdown]
# <a href="https://colab.research.google.com/github/nrcriverside3070-source/MIS2800/blob/main/Prep1_Intro_to_Colab_START.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prep 1: Google Colab, Getting Started
#
# This prep file follows along with the Batch 2 videos (slides 28–36). Watch each video segment and run and complete the matching cells below along with it. You will need to download 'BostonHousing.csv' from Canvas.

# %% [markdown]
# **Name:** *(Nathan Collado)*
#
# **Date:** *(9/1/2026)*

# %% [markdown]
# ## 1. The Colab Interface
#
# A Colab notebook (markdown file) is built from **cells**:
# - **Code cells** — where you write and run Python
# - **Text cells** (like this one!) — for notes and headers, written in Markdown
#
# Run a cell by clicking the ▶ button, or pressing **Shift + Enter**.
#
# **Try it:** run the code cell below.

# %%
# This is a code cell. Run me with Shift + Enter.
print("Hello, QBA 3720!")
# Out:
# Hello, QBA 3720!

# %% [markdown]
# **Your turn:** add a new code cell below this one (use the `+ Code` button) and print your own name.

# %% [markdown]
# ## 2. Cell Order & Variable Memory
#
# Colab runs cells in the **order you run them** not automatically top to bottom. Variables persist after a cell runs, until you restart the runtime.
#
# **Try it:** run the two cells below *in order* (first, then second). Then go back and re-run the *first* cell only, and predict what happens if you re-run the *second* cell again without changing it.
#
# **Your Prediction Here:**

# %%
# Cell A
favorite_number = 7
print("favorite_number is set to", favorite_number)
# Out:
# favorite_number is set to 7

# %%
# Cell B
favorite_number = favorite_number * 2
print("favorite_number is now", favorite_number)
# Out:
# favorite_number is now 14

# %% [markdown]
# **Question:** If you run Cell B multiple times in a row without re-running Cell A, what happens to `favorite_number`? Write your answer in the text cell below.
#
# **Your answer here:**

# %% [markdown]
# **Good habit before submitting any notebook:** `Runtime → Restart and run all`. This confirms your notebook runs cleanly from top to bottom, similar to the way it will be graded.

# %% [markdown]
# ## 3. Loading Packages in Colab
#
# Colab comes with most packages this course needs already installed. To use a package, **import it** at the top of your notebook. Good habit: keep all your imports together in your first code cell.
#
# **Try it:** run the cell below to load the three packages we'll use most this semester.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Hopefully, Packages loaded successfully! If not, try to install them!")
# Out:
# Hopefully, Packages loaded successfully! If not, try to install them!

# %% [markdown]
# **Note:** if you ever need a package that isn't installed, you can run `!pip install package_name` in a code cell before importing it. Imports only last for your current session — after `Runtime → Restart`, you'll need to re-run your import cell.

# %% [markdown]
# ## 4. Loading Data Into Colab: Your Options
#
# There are three common ways to get a file into your notebook. Whichever method you use, the goal is the same: get the file into a pandas DataFrame. Let's work on loading the BostonHousing.csv file from Canvas
#
# ### Option A — Quick Upload
# Good for a single working session. The file disappears when your runtime restarts.

# %%
from google.colab import files

# Uncomment the line below, run this cell, and select a CSV file from your computer
uploaded = files.upload()
# Out:
#      <input type="file" id="files-55661354-92aa-475d-92e9-ce0a7d63eda6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55661354-92aa-475d-92e9-ce0a7d63eda6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Option B — Mount Google Drive
# Best if you'll reuse the same file all semester. Approve access when prompted.

# %%
from google.colab import drive

# Uncomment the line below and run this cell
# drive.mount('/content/drive')

# Once mounted, your file lives at a path like:
# '/content/drive/MyDrive/yourfile.csv'

# %% [markdown]
# ### Option C — Load from a URL
# No upload needed at all if you have a direct link to the file.

# %%
# Example (uncomment and replace with a real URL to try it):
# df = pd.read_csv('https://raw.githubusercontent.com/example/data.csv')
# df.head()

# %% [markdown]
# **NOTE:** I recommened that you ALWAYS use Option A where you reference a file on your own computer, that will be the method I teach for this class.

# %% [markdown]
# ## 5. Formatting HW and Prep Files (working with Markdown files)
#
# While this prep file introduces some of the basics with formatting between text and code in Colab, there exists a lot of tools and formatting to make your HW and Prep files easy to digest and comprehend. For example, HTML and figure/table making can be incorporated, to name a few. A data analyst who cannot put together their results in a manner that is easily readible to a general audience, is NOT good at their job.
#
# **Please view how the text is formatted in this prep file and take a look at the video link and guide markdown files in 'General Information' on Canvas.**

# %% [markdown]
# ## 6. Common First-Use Hiccups
#
# - **"It's not running!"** — Check the `Runtime` menu; you may need to reconnect.
# - **"My code worked before, but now it's broken"** — A variable may have changed from running cells out of order. Try `Runtime → Restart and run all`.
# - **"I can't find my file"** — Check `My Drive → Colab Notebooks` in Google Drive.
# - **Still stuck?** Bring it to Office Hours (Tue/Thu, 3–5PM on Teams) or email Dr. Miller.
#
# ---
#
# You're done with Prep 1! Once you've run every cell top to bottom without errors, you're ready to move on.
